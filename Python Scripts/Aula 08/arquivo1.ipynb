# %%
import numpy as np
import cv2

# %%
#Função para desenhar círculo pelo mouse
def circulo(event, x, y, flag, param):
    if(event == cv2.EVENT_LBUTTONDOWN):
        cv2.circle(imagem, (x, y), 100, (0, 255, 255), 10)
    elif(event == cv2.EVENT_RBUTTONDOWN):
        cv2.circle(imagem, (x, y), 100, (255, 255, 0), -1)

name = 'minha_imagem'
cv2.namedWindow(winname = name)

cv2.setMouseCallbSkip to left side bar
>
/
/Python Scripts/Aula 08/
Name
Last Modified

Selection deleted
import numpy as np
import cv2
ack(name, circulo)

#Apreentação da imagem com o OpenCV
imagem = np.zeros((400, 400, 3))

while True:

    cv2.imshow(name, imagem)

    if(cv2.waitKey(20) & 0xFF == 27):
        break

cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x907dd60) is not the object's thread (0x9290900).
# Cannot move to target thread (0x907dd60)
#
# QObject::moveToThread: Current thread (0x907dd60) is not the object's thread (0x9290900).
# Cannot move to target thread (0x907dd60)
#
# QObject::moveToThread: Current thread (0x907dd60) is not the object's thread (0x9290900).
# Cannot move to target thread (0x907dd60)
#
# QObject::moveToThread: Current thread (0x907dd60) is not the object's thread (0x9290900).
# Cannot move to target thread (0x907dd60)
#
# QObject::moveToThread: Current thread (0x907dd60) is not the object's thread (0x9290900).
# Cannot move to target thread (0x907dd60)
#
# QObject::moveToThread: Current thread (0x907dd60) is not the object's thread (0x9290900).
# Cannot move to target thread (0x907dd60)
#
# QObject::moveToThread: Current thread (0x907dd60) is not the object's thread (0x9290900).
# Cannot move to target thread (0x907dd60)
#
# ...
